# %% [markdown]
# # Notebook Setup

# %%
import sys, os
sys.path.append(os.path.abspath('..'))

# %%
# setup bokeh
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="094a45c1-5b56-4087-915a-fa90c246568c">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Tamagotchi Base

# %% [markdown]
# ## Appetite drops off with age

# %%
from tamagotchi.math_utils import sigmoid 
import numpy as np
from math import log

p = figure(plot_width=400, plot_height=400)

# add a line renderer
age_series = np.arange(1/365, 10, 1/120)
p.line(age_series, 0.5+np.log(age_series)/log(1/365)*0.5, line_width=2)

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="304158a9-73a0-4e00-bc48-df500b669956"></div>
# </div>

# %%
import numpy as np
# Out:
# Help on built-in function arange in module numpy.core.multiarray:
#
# arange(...)
#     arange([start,] stop[, step,], dtype=None)
#
#     Return evenly spaced values within a given interval.
#
#     Values are generated within the half-open interval ``[start, stop)``
#     (in other words, the interval including `start` but excluding `stop`).
#     For integer arguments the function is equivalent to the Python built-in
#     `range <http://docs.python.org/lib/built-in-funcs.html>`_ function,
#     but returns an ndarray rather than a list.
#
#     When using a non-integer step, such as 0.1, the results will often not
#     be consistent.  It is better to use ``linspace`` for these cases.
#
#     Parameters
#     ----------
#     start : number, optional
#         Start of interval.  The interval includes this value.  The default
#         start value is 0.
#     stop : number
#         End of interval.  The interval does not include this value, except
# ...
